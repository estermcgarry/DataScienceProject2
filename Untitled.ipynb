# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

sns.set()
# %matplotlib inline

# %%
df = pd.read_csv('AnimalWelfareRisk-19205519.cleaned2.csv', keep_default_na=True, sep=',\s+', delimiter=',', skipinitialspace=True)

# %%
df.head()
# Out:
#   animal_id      datetime_intake  \
# 0   A783167  2018-12-15 13:56:00
# 1   A753133  2017-07-02 11:03:00
# 2   A760404  2017-10-17 17:38:00
# 3   A773372  2018-05-31 11:52:00
# 4   A789156  2019-02-16 11:25:00
#
#                                       found_location      intake_type  \
# 0                  11711 Domain Drive in Austin (TX)  Owner Surrender
# 1                   9414 N Lamar Blvd in Austin (TX)            Stray
# 2                    5301 Wasson Road in Austin (TX)            Stray
# 3                                        Austin (TX)  Owner Surrender
# 4  Westgate Boulevard And Bushnell Drive in Austi...            Stray
#
#   intake_condition animal_type_intake              breed_intake  \
# 0           Normal                Cat  Domestic Medium Hair Mix
# 1           Normal                Dog              Pit Bull Mix
# 2           Normal                Cat    Domestic Shorthair Mix
# 3           Normal                Cat    Domestic Shorthair Mix
# 4           Normal                Dog     Yorkshire Terrier Mix
#
#         color_intake     datetime_outcome        date_of_birth  ...  \
# 0         Blue Tabby  2018-12-15 18:38:00  2018-06-26 00:00:00  ...
# 1        Black/White  2017-07-10 18:42:00  2017-01-02 00:00:00  ...
# 2              Black  2017-10-17 19:01:00  2017-10-14 00:00:00  ...
# 3  Brown Tabby/White  2018-07-06 14:35:00  2017-05-31 00:00:00  ...
# 4        Brown/Black  2019-02-20 16:49:00  2009-02-16 00:00:00  ...
#
#    neuter_status_outcome age_upon_intake_days age_upon_outcome_days  \
# 0               Neutered                  152                   152
# 1               Neutered                  152                   182
# 2           Not neutered                    3                     3
# 3               Neutered                  365                   365
# 4               Neutered                 3650                  3650
#
#               time_in_shelter  month_intake  month_outcome  \
# 0   0 days 04:42:00.000000000            12             12
# 1   8 days 07:39:00.000000000             7              7
# 2   0 days 01:23:00.000000000            10             10
# 3  36 days 02:43:00.000000000             5              7
# 4   4 days 05:24:00.000000000             2              2
#
#   time_in_shelter_days   found_city       animal_breed  animal_color
# 0                  0.0  Austin (TX)     Domestic Mixed          Blue
# 1                  8.0  Austin (TX)           Pit Bull         Black
# 2                  0.0  Austin (TX)     Domestic Mixed         Black
# 3                 36.0  Austin (TX)     Domestic Mixed         Brown
# 4                  4.0  Austin (TX)  Yorkshire Terrier         Brown
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (1000, 23)

# %%
train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)

# %%
df_copy = train_set.copy()

# %%
df_copy.shape
# Out:
# (800, 23)

# %%
df_copy.head()
# Out:
#     animal_id      datetime_intake                            found_location  \
# 29    A729279  2016-06-15 15:35:00  10505 S Ih 35 Frontage Rd in Austin (TX)
# 535   A675571  2014-03-29 13:08:00      12032 Lincolnshire Dr in Austin (TX)
# 695   A756798  2019-10-12 14:45:00                               Travis (TX)
# 557   A760739  2017-10-23 11:42:00       Blacno Vista Cove in Del Valle (TX)
# 836   A756573  2017-08-22 11:14:00         Loyola And Milrace in Travis (TX)
#
#          intake_type intake_condition animal_type_intake  \
# 29             Stray           Normal                Cat
# 535            Stray           Normal              Other
# 695  Owner Surrender           Normal                Cat
# 557            Stray           Normal                Cat
# 836            Stray           Normal                Dog
#
#                breed_intake  color_intake     datetime_outcome  \
# 29   Domestic Shorthair Mix        Torbie  2016-06-16 09:00:00
# 535        English Spot Mix   White/Black  2014-04-29 18:50:00
# 695  Domestic Shorthair Mix   Brown Tabby  2017-10-28 18:02:00
# 557  Domestic Shorthair Mix  Silver Tabby  2017-10-31 11:21:00
# 836           Dachshund Mix   Black/White  2017-09-02 14:48:00
#
#            date_of_birth  ...  neuter_status_outcome age_upon_intake_days  \
# 29   2013-06-15 00:00:00  ...               Neutered                 1095
# 535  2013-03-29 00:00:00  ...           Not neutered                  365
# 695  2017-06-25 00:00:00  ...               Neutered                  730
# 557  2017-09-14 00:00:00  ...           Not neutered                   30
# 836  2016-08-22 00:00:00  ...               Neutered                  365
#
#     age_upon_outcome_days                time_in_shelter  month_intake  \
# 29                   1095      0 days 17:25:00.000000000             6
# 535                   365     31 days 05:42:00.000000000             3
# 695                   122  -714 days +03:17:00.000000000            10
# 557                    30      7 days 23:39:00.000000000            10
# 836                   365     11 days 03:34:00.000000000             8
#
#      month_outcome time_in_shelter_days      found_city    animal_breed  \
# 29               6                  0.0     Austin (TX)  Domestic Mixed
# 535              4                 31.0     Austin (TX)           other
# 695             10                  NaN     Travis (TX)  Domestic Mixed
# 557             10                  7.0  Del Valle (TX)  Domestic Mixed
# 836              9                 11.0     Travis (TX)       Dachshund
#
#      animal_color
# 29         Torbie
# 535         White
# 695         Brown
# 557         other
# 836         Black
#
# [5 rows x 23 columns]

# %%
df_copy.describe()

# %%
df_copy.corr()
